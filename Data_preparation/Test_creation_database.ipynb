# %%
# Import de librairie
import pandas as pd

# %%
annees = [str(annee) for annee in range(2003, 2022)]

# %%
Data_dechets= []
for annee in annees:
    data_d = pd.read_excel(
        "Dechet_par_habitant.xls",
        sheet_name=annee,        
        skiprows=1,              
        usecols="A:B",          
        header=None,             
        names=["Commune", "Dechet_par_habitant_kg"]
    )
    data_d["Année"] = int(annee)     
    Data_dechets.append(data_d) 

Data_dechets_final = pd.concat(Data_dechets, ignore_index=True)

print(Data_dechets_final)
# Out:
#            Commune Dechet_par_habitant_kg  Année
# 0    Aire-la-Ville                  440.7   2003
# 1          Anières                  622.3   2003
# 2           Avully                  482.1   2003
# 3            Avusy                  447.9   2003
# 4        Bardonnex                  441.1   2003
# ..             ...                    ...    ...
# 853        Troinex             464.605701   2021
# 854    Vandoeuvres             613.053812   2021
# 855        Vernier             408.657247   2021
# 856        Versoix             371.930217   2021
# 857        Veyrier             535.479049   2021
#
# [858 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
